# %% [markdown]
# # Sample documentation for some one liners
# And a description
# * Some inline ordered
# * Lists because
# * This is all markdown
#
# You can expand/collapse output panes by clicking on `Out[1]:`

# %%
Get-ChildItem Env:
# Out:
# Name                           Value
# ----                           -----
# BINDER_PORT                    tcp://10.15.253.247:80
# BINDER_PORT_80_TCP             tcp://10.15.253.247:80
# BINDER_PORT_80_TCP_ADDR        10.15.253.247
# BINDER_PORT_80_TCP_PORT        80
# BINDER_PORT_80_TCP_PROTO       tcp
# BINDER_SERVICE_HOST            10.15.253.247
# BINDER_SERVICE_PORT            80
# CONDA_DIR                      /opt/conda
# CPU_GUARANTEE                  0.1
# CPU_LIMIT                      2.0
# CULL_CONNECTED                 1
# CULL_INTERVAL                  60
# CULL_KERNEL_TIMEOUT            600
# CULL_TIMEOUT                   600
# DEBIAN_FRONTEND                noninteractive
# EMAIL                          thmsrynr-jupyter-powershell-phf6fcvj@local
# GIT_AUTHOR_NAME                thmsrynr-jupyter-powershell-phf6fcvj
# GIT_COMMITTER_NAME             thmsrynr-jupyter-powershell-phf6fcvj
# HOME                           /home/jovyan
# ...

# %% [markdown]
# # More documentation for something else
#
# Full mark down support!
#
# [Supports links too](http://pcl.com) (right click, new tab to not lose this page).
#
# This line of code is for getting all the contents of the current directory. `gci` is an alias for `get-childitem`

# %%
gci
# Out:
# Directory: /home/jovyan
#
#
# Mode                LastWriteTime         Length Name
# ----                -------------         ------ ----
# d-----          2/20/18   9:28 AM                work
# ------          4/23/18   9:15 PM          21167 Example.ipynb
# ------          4/23/18   8:44 PM           1121 LICENSE.md
# ------          4/23/18   8:44 PM          12114 nteract - plotly.ipynb
# ------          4/23/18   8:44 PM         168840 ReadMe.ipynb
# ------          4/23/18   8:44 PM           2270 ReadMe.md
# ------          4/23/18   8:44 PM           8453 Release.ipynb
